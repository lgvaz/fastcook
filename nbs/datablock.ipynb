# %% [markdown]
# # Datablock
# > Go [here](https://github.com/fastai/fastai2/blob/master/nbs/50_tutorial.datablock.ipynb) for quick examples or [here](https://muellerzr.github.io/fastblog/datablock/2020/03/21/DataBlockAPI.html) for a more detailed look.

# %%
from fastai2.vision.all import *

# %%
source = untar_data(URLs.COCO_TINY)

# %% [markdown]
# ## Check transforms on a single item

# %%
dblock = DataBlock((ImageBlock), get_items=get_image_files,
                  item_tfms=[RandomResizedCrop(128, min_scale=.3)])

# %%
dls = dblock.dataloaders(source)
dls.train.get_idxs = lambda: Inf.ones
dls.show_batch()
